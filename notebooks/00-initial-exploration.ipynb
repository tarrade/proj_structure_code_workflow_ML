# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %load_ext watermark
# %watermark -v -n -m -p numpy,scipy,sklearn,pandas
# Out:
# Sat May 05 2018
#
# CPython 3.5.5
# IPython 6.3.1
#
# numpy 1.14.2
# scipy 1.0.1
# sklearn 0.19.1
# pandas 0.22.0
#
# compiler   : GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)
# system     : Darwin
# release    : 15.6.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 8
# interpreter: 64bit

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import os
PROJ_ROOT = os.path.abspath(os.path.join(os.pardir))
print(PROJ_ROOT)
# Out:
# /Users/tarrade/Desktop/Work/Data_Science/Tutorials_Codes/Python/proj_structure_code_workflow_ML

# %%
os.path.join(PROJ_ROOT, 'data', 'raw', 'iris.csv')
# Out:
# '/Users/tarrade/Desktop/Work/Data_Science/Tutorials_Codes/Python/proj_structure_code_workflow_ML/data/raw/iris.csv'

# %%
data_fname = os.path.join(PROJ_ROOT, 'data', 'raw', 'iris.csv')
dframe = pd.read_csv(data_fname, header=None)
dframe.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
dframe.columns = ['x0', 'x1', 'x2', 'x3', 'y']
dframe.head()
# Out:
#     x0   x1   x2   x3            y
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
sns.pairplot(dframe, vars=['x0', 'x1', 'x2', 'x3'], hue='y')

# %% [markdown]
# # Updating the notebook

# %%
# %load_ext watermark
# %watermark -v -n -m -p numpy,scipy,sklearn,pandas
 
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import os
PROJ_ROOT = os.path.abspath(os.path.join(os.pardir))
print(PROJ_ROOT)
import sys
sys.path.append(os.path.join(PROJ_ROOT, 'src'))
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Sat May 05 2018
#
# CPython 3.5.5
# IPython 6.3.1
#
# numpy 1.14.2
# scipy 1.0.1
# sklearn 0.19.1
# pandas 0.22.0
#
# compiler   : GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)
# system     : Darwin
# release    : 15.6.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 8
# interpreter: 64bit
# /Users/tarrade/Desktop/Work/Data_Science/Tutorials_Codes/Python/proj_structure_code_workflow_ML

# %% [markdown]
# ## Importing code from src

# %%
import sys
sys.path.append(os.path.join(PROJ_ROOT, 'src'))
from data.preprocess import read_raw_data, preprocess_data
from visualization.exploratory import exploratory_visualization

# %%
sys.path.append(os.path.join(PROJ_ROOT, 'src'))

# %%
sys.path
# Out:
# ['',
#  '/Users/tarrade/anaconda/envs/env_code_structure/lib/python35.zip',
#  '/Users/tarrade/anaconda/envs/env_code_structure/lib/python3.5',
#  '/Users/tarrade/anaconda/envs/env_code_structure/lib/python3.5/plat-darwin',
#  '/Users/tarrade/anaconda/envs/env_code_structure/lib/python3.5/lib-dynload',
#  '/Users/tarrade/anaconda/envs/env_code_structure/lib/python3.5/site-packages',
#  '/Users/tarrade/anaconda/envs/env_code_structure/lib/python3.5/site-packages/IPython/extensions',
#  '/Users/tarrade/.ipython',
#  '/Users/tarrade/Desktop/Work/Data_Science/Tutorials_Codes/Python/proj_structure_code_workflow_ML/src',
#  '/Users/tarrade/Desktop/Work/Data_Science/Tutorials_Codes/Python/proj_structure_code_workflow_ML/src',
#  'src',
#  '/Users/tarrade/Desktop/Work/Data_Science/Tutorials_Codes/Python/proj_structure_code_workflow_ML/src',
#  '/Users/tarrade/Desktop/Work/Data_Science/Tutorials_Codes/Python/proj_structure_code_workflow_ML/src']

# %% [markdown]
# ## Loading raw data

# %%
data_fname = os.path.join(PROJ_ROOT, 'data', 'raw', 'iris.csv')
raw_data = read_raw_data(data_fname)
raw_data.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %% [markdown]
# ## Preprocessing data

# %%
preprocessed_data = preprocess_data(raw_data)
preprocessed_data.head()
# Out:
#     x0   x1   x2   x3            y
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %% [markdown]
# ## And plotting

# %%
exploratory_visualization(preprocessed_data)

# %% [markdown]
# ## Changing the code
# the line need to be added at the begining of the notebook to have the code reloaded

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
exploratory_visualization(preprocessed_data)
